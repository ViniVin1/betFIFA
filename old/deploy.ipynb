# %%
import pandas as pd
from datetime import datetime
import streamlit as st
import joblib

modelo = joblib.load('modelo.joblib')

# %%
df = pd.read_csv('base_predict.csv')
df['horario'] = pd.to_datetime(df['horario'], format='%H:%M').apply(lambda x: x.strftime('%H:%M'))
df = df[df['horario'] >= '15:30']
df
# Out:
#            data horario                 time_casa  player_casa  gols_casa  \
# 188  2024-02-21   15:38             Villarreal CF        Rodja          0
# 189  2024-02-21   15:38                      Roma         Zyen          0
# 200  2024-02-21   15:30               Real Madrid         Gaga          0
# 201  2024-02-21   15:30                 Barcelona          Taz          0
# 202  2024-02-21   15:48  Paris Saint-Germain F.C.          Sef          0
# ..          ...     ...                       ...          ...        ...
# 375  2024-02-21   19:54                 Barcelona  LaikingDast          0
# 376  2024-02-21   20:06               Real Madrid         Kray          0
# 377  2024-02-21   20:06           Manchester City     MeLToSik          0
# 378  2024-02-21   20:18                 Barcelona  LaikingDast          0
# 379  2024-02-21   20:18             Bayern Munich        Kodak          0
#
#      gols_fora   player_fora                 time_fora  total_gols
# ...

# %%
time_casa = []
player_casa = []
player_fora = []
time_fora = []

for i in df.itertuples():
    time_casa.append('time_casa' + '_' + i[3])
    time_fora.append('time_fora' + '_' + i[8])
    player_casa.append('player_casa' + '_' + i[4])
    player_fora.append('player_fora' + '_' + i[7])

data = {}
data['time_casa'] = time_casa
data['player_casa'] = player_casa
data['player_fora'] = player_fora
data['time_fora'] = time_fora

valores = pd.DataFrame(data)
previsao = modelo.predict(valores)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 19
#      16 data['time_fora'] = time_fora
#      18 valores = pd.DataFrame(data)
# ---> 19 previsao = modelo.predict(valores)
#
# File c:\Users\vinicius.frodrigues\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:286, in LinearModel.predict(self, X)
#     272 def predict(self, X):
#     273     """
#     274     Predict using the linear model.
#     275
#    (...)
#     284         Returns predicted values.
#     285     """
# --> 286     return self._decision_function(X)
#
# File c:\Users\vinicius.frodrigues\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1120, in ElasticNet._decision_function(self, X)
#    1118     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#    1119 else:
# ...
